# %%
import pandas as pd

from omero_screen_analysis.featureplot import feature_plot

# %%
df = pd.read_csv("../example_data_3x.csv")

# %%
conditions = ["NT", "CCNA2", "CDK4"]

# %%
feature_plot(
    df=df,
    feature="intensity_mean_p21_nucleus",
    conditions=conditions,
    condition_col="condition",  # default
    selector_col="cell_line",  # default
    selector_val="RPE-1_WT",
    title_str="p21",
    save=False,
    path=None,
)
# Out:
# #41b6e6
# #dc582a
# #ffc845

# %%
feature_plot(
    df=df,
    feature="area_cell",
    conditions=conditions,
    condition_col="condition",  # default
    selector_col="cell_line",  # default
    selector_val="RPE-1_WT",
    title_str="cell area",
    save=False,
    path=None,
)
# Out:
# #41b6e6
# #dc582a
# #ffc845
# /Users/hh65/code/omero-screen-analysis/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/hh65/code/omero-screen-analysis/.venv/lib/python3.12/site-packages/seaborn/categorical.py:3399: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
