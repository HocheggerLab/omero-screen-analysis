# %%
import pandas as pd

from omero_screen_analysis.countplot import count_plot

df = pd.read_csv("../example_data_3X.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/code/omero-screen-analysis/.venv/lib/python3.12/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~/code/omero-screen-analysis/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:870, in _rc_params_in_file(fname, transform, fail_on_error)
#     869 rc_temp = {}
# --> 870 with _open_file_or_url(fname) as fd:
#     871     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/code/omero-screen-analysis/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:847, in _open_file_or_url(fname)
# ...

# %%
conditions = ["NT", "CCNA2", "CDK4"]

# %%
count_plot(
    df=df,
    norm_control="NT",
    conditions=conditions,
    condition_col="condition",
    selector_col="cell_line",
    selector_val="RPE-1_WT",
    title_str="test",
    save=False,
)
# Out:
# /Users/hh65/code/omero-screen-analysis/.venv/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
