# %%
import pandas as pd

from omero_screen_analysis.combplot import combplot

df = pd.read_csv("../example_data.csv")

# %%
conditions = ["NT", "SCR", "CCNA2", "CDK4"]

# %%
combplot(
    df,
    conditions,
    "intensity_mean_p21_nucleus",
    feature_y_lim=8000,
    selector_val="RPE-1_WT",
    x_col="condition",  # default
    selector_col="cell_line",  # default
    title_str="p21",
    cell_number=3000,
    save=False,
)
