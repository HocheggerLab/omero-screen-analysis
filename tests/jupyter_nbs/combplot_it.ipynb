# %%
import pandas as pd

from omero_screen_analysis.combplot import comb_plot

df = pd.read_csv("../example_data_3x.csv")

# %%
df.cell_line.unique()
# Out:
# array(['RPE-1_WT'], dtype=object)

# %%
conditions = ["NT", "CCNA2", "CDK4"]

# %%
comb_plot(
    df=df,
    conditions=conditions,
    feature_col="intensity_mean_p21_nucleus",
    feature_y_lim=6000,
    condition_col="condition",  # default
    selector_col="cell_line",  # default
    selector_val="RPE-1_WT",
    title_str="test",
    cell_number=3000,
    save=False,
    path=None,
)

# %%
from omero_screen_analysis.cellcycleplot import cellcycle_plot

cellcycle_plot(
    df=df,
    conditions=conditions,
    condition_col="condition",  # default
    selector_col="cell_line",  # default
    selector_val="RPE-1_WT",
    save=False,
    path=None,
)
